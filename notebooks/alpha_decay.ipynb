# %% [markdown]
# # Alpha Decay Analysis
#
# Measure how quickly signals decay after generation.

# %%
import polars as pl
from qsip.db import TimescaleDB

db = TimescaleDB('postgres://qsip:qsip@localhost:5432/qsip?sslmode=disable')
signals = db.get_signals(limit=1000)
bt = db.get_backtests()  # extend DB method if needed
# TODO: implement alpha decay plots
